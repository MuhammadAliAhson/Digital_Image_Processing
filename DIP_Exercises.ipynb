# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
img = cv2.imread("/kaggle/input/natural-images/natural_images/person/person_0000.jpg")
plt.imshow(img)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
def apply_kernal(img,kernal):
    return cv2.filter2D(img,-1,kernal)
kernal = np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])
d = apply_kernal(img,kernal)
d.shape
plt.imshow(d,cmap='gray')
for i in range(2):
    plt.subplot(1,2,i+1)
    plt.imshow(img,cmap='gray')
    plt.imshow(d,cmap='gray')
    plt.axis('off')
e = img - d
plt.imshow(e)

# %%
img = cv2.imread("/kaggle/input/natural-images/natural_images/person/person_0000.jpg")
plt.imshow(img)

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
def apply_kernal(img,kernal):
    return cv2.filter2D(img,-1,kernal)

# %%
kernal = np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])
d = apply_kernal(img,kernal)
d.shape
plt.imshow(d,cmap='gray')

# %%
for i in range(2):
    plt.subplot(1,2,i+1)
    plt.imshow(img,cmap='gray')
    plt.imshow(d,cmap='gray')
    plt.axis('off')

# %%
e = img - d
plt.imshow(e)

# %%
img = img+e
plt.imshow(img)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("/kaggle/input/natural-images/natural_images/person/person_0000.jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)

def apply_kernel(img, kernel):
    return cv2.filter2D(img, -1, kernel)

kernel = np.array([[0, -1, 0],
                   [-1, 5, -1],
                   [0, -1, 0]])

filtered_img = apply_kernel(img_gray, kernel)

enhanced_img = 255 - filtered_img  # Invert intensity values

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(enhanced_img, cmap='gray')
plt.title('Enhanced Image')

plt.show()

# %%
import math

def log(r):
    return np.log(1 + r)
    
a = log(img)

# %%
plt.imshow(a,cmap='gray')

# %%
def power(r,n):
    return np.power(r,n)

# %%
a = power(img,2)
plt.imshow(a,)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def sharpen_image(img):
    # Define Laplacian filter kernel
    kernel = np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])
    
    # Apply Laplacian filter independently to each color channel
    sharpened_img = np.zeros_like(img)
    for i in range(3):  # Iterate over R, G, B channels
        sharpened_img[:,:,i] = cv2.filter2D(img[:,:,i], -1, kernel)
    
    # Ensure pixel values are within valid range [0, 255]
    sharpened_img = np.clip(sharpened_img, 0, 255).astype(np.uint8)
    
    return sharpened_img

# Read the image
img = cv2.imread("/kaggle/input/natural-images/natural_images/person/person_0000.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Sharpen the image
sharpened_img = sharpen_image(img)

# Plotting
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(sharpened_img)
plt.title('Sharpened Image')
plt.axis('off')

plt.show()
